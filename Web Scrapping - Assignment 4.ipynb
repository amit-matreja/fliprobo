# %% [markdown]
# # Web Scraping Assignment 4 ( Selenium):

# %%
#Importing required Libraries for assignment
import pandas as pd
import time
import selenium
# importing selenium webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
# importing required exceptions which needs to be handled
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
import requests

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

# %% [markdown]
# Q1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
#Opening the required website
url="https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos "
driver.get(url)
time.sleep(2)

# %%
# Lets create list for scraping required data

rank=[]
name=[]
artist=[]
upload_date=[]
views=[]

# %%
# Rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]"):
        rank.append(i.text)
except NoSuchElementException:
    rank.append("_")
    
# Name
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]"):
        name.append(i.text)
except NoSuchElementException:
    name.append("_")
    
# Artist
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]"):
        artist.append(i.text)
except NoSuchElementException:
    artist.append("_")

# upload date
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]"):
        upload_date.append(i.text)
except NoSuchElementException:
    upload_date.append("_")
    
# views
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]"):
        views.append(i.text)
except NoSuchElementException:
    views.append("_")
    
# Creating DataFrame fr scraped data
df = pd.DataFrame({})
df['Rank']=rank
df['Name']=name
df['Artist']=artist
df['Upload Date']=upload_date
df['Views']=views

# %%
df
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[5]
# 2    3.                       "Johny Johny Yes Papa"[11]
# 3    4.                               "Shape of You"[12]
# 4    5.                              "See You Again"[14]
# 5    6.                                  "Bath Song"[19]
# 6    7.  "Learning Colors – Colorful Eggs on a Farm"[20]
# 7    8.   "Masha and the Bear – Recipe for Disaster"[21]
# 8    9.                                "Uptown Funk"[22]
# 9   10.                "Phonics Song with Two Words"[23]
# 10  11.                              "Gangnam Style"[24]
# 11  12.                             "Dame Tu Cosita"[29]
# 12  13.                                      "Sugar"[30]
# 13  14.                                      "Sorry"[31]
# 14  15.                                       "Roar"[32]
# ...

# %% [markdown]
# Q2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
#
# A) Match title (I.e. 1
# st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url="https://www.bcci.tv/"
driver.get(url)
time.sleep(2)

# %%
# lets click to reach international fixture page.
select=driver.find_element(By.XPATH,"//div[@class='navbar-collapse collapse']/ul/li[2]/a")
driver.get(select.get_attribute("href"))
time.sleep(2)

# %%
# lets create empty list of items to be scrapped
match_title=[]
series=[]
place=[]
date=[]
Time=[]

# %%
#match title
for i in driver.find_elements(By.XPATH,"//div[@class='tab-inner-content']/div/div/div/div[4]/div"):
    match_title.append(i.text)
# series
for i in driver.find_elements(By.XPATH,"//span[@class='ng-binding']"):
    series.append(i.text)
#place
for i in driver.find_elements(By.XPATH,"//div[@class='tab-inner-content']/div/div/div/div[4]/div"):
    place.append(i.text)
#date
for i in driver.find_elements(By.XPATH,"//div[@class='match-card-left match-schedule']/h5"):
    date.append(i.text)
#Time
for i in driver.find_elements(By.XPATH,"//div[@class='match-top-info d-flex align-items-center justify-content-between']/div[2]/h5"):
    Time.append(i.text.replace)

# Creating data frame
df=pd.DataFrame(list(zip(match_title[0:5],series[0:5],place[0:5],date[0:5],Time[0:5])),columns=["Match Title","Series","Place","Date","Time"])
df
# Out:
#                                       Match Title  \
# 0  2nd Test - The Wanderers Stadium, Johannesburg
# 1                  3rd Test - Newlands, Cape Town
# 2                    1st ODI - Boland Park, Paarl
# 3                    2nd ODI - Boland Park, Paarl
# 4                   3rd ODI - Newlands, Cape Town
#
#                                            Series  \
# 0  INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 1  INDIA TOUR OF SOUTH AFRICA TEST SERIES 2021-22
# 2   INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 3   INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
# 4   INDIA TOUR OF SOUTH AFRICA ODI SERIES 2021/22
#
#                                             Place         Date  \
# 0  2nd Test - The Wanderers Stadium, Johannesburg   3 JAN 2022
# 1                  3rd Test - Newlands, Cape Town  11 JAN 2022
# 2                    1st ODI - Boland Park, Paarl  19 JAN 2022
# 3                    2nd ODI - Boland Park, Paarl  21 JAN 2022
# ...

# %% [markdown]
# Q3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
#
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium  exception handling page through code

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url="https://www.guru99.com/"
driver.get(url)
time.sleep(2)

# %%
# lets create empty list for data extraction
name=[]
description=[]

# %%
# click on Selenium
sel=driver.find_element(By.XPATH,"//li//a[@title='Selenium']")
sel.click()
time.sleep(2)

# %%
#Click on Exception Handling
driver.find_element(By.XPATH,'//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()
time.sleep(2)

#Scraping name
for i in driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td[1]"):
            name.append(i.text)

#Scraping description
for i in driver.find_elements(By.XPATH,"//table[@class='table table-striped']/tbody/tr/td[2]"):
            description.append(i.text)
        
# creating the dataframe from the scraped data
df=pd.DataFrame({})
df['Exception_Name']=name
df['Description']=description
df
# Out:
#                          Exception_Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# Q4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP
# D) GSDP
# E) Share
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url=" http://statisticstimes.com/"
driver.get(url)
time.sleep(2)

# %%
# Click on Economy
driver.find_element(By.XPATH,"//div[@class='navbar']/div[2]/button").click()

# Click on India
driver.find_element(By.XPATH,"//div[@class='dropdown-content']/a[3]").click()
time.sleep(2)

# %%
# Click on GDP of Indian Economy
GDP = driver.find_element(By.XPATH,'//html/body/div[2]/div[2]/div[2]/ul/li[1]/a').click()
time.sleep(3)

# %%
# lets create empty list now
rank=[]
state=[]
gsdp1=[]
gsdp2=[]
share=[]
gdp=[]

# %%
# rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        rank.append(i.text)
except NoSuchElementException:
    rank.append("_")
    
# state
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        state.append(i.text)
except NoSuchElementException:
    state.append("_")
    
# gsdp1 at current price (19-20)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]"):
        gsdp1.append(i.text)
except NoSuchElementException:
    gsdp1.append("_")
    
# gsdp2 at current price (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]"):
        gsdp2.append(i.text)
except NoSuchElementException:
    gsdp2.append("_")
    
# share
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]"):
        share.append(i.text)
except NoSuchElementException:
    share.append("_")
    
# gdp $ billion
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]"):
        gdp.append(i.text)
except NoSuchElementException:
    gdp.append("_")
    
# lets Create DataFrame
df = pd.DataFrame({})
df['Rank'] = rank
df['State'] = state
df['GSDP at current price (19-20)'] = gsdp1
df['GSDP at current price (18-19)'] = gsdp2
df['Share(18-19)'] = share
df[' GDP($ billion)'] = gdp
df
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share(18-19)  GDP($ billion)
# 0                      2,632,792       13.94%         399.921
# ...

# %% [markdown]
# Q5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url=" https://github.com/"
driver.get(url)
time.sleep(2)

# %%
#Getting explore button and clicking on it
explore = driver.find_element(By.XPATH,"//html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()
explore
#Selecting trending option
trend_url = driver.find_element(By.XPATH,"//div[@class='container-xl d-lg-flex flex-items-center p-responsive']/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# %%
# lets create empty list
repository_title=[]
descrip=[]
contributors=[]
language=[]

# %%
# Scraping Repository Title data
title = driver.find_elements(By.XPATH,"//span[@class='text-normal']")
for i in title:
    repository_title.append(i.text)
    
# Scraping Repository Description data
try:
    for i in driver.find_elements(By.XPATH,"//p[@class='col-9 color-fg-muted my-1 pr-4']"):
        descrip.append(i.text)
except NoSuchElementException:
    descrip.append('-')


# Scraping Contributors Count data
try:
    for i in driver.find_elements(By.XPATH,"//div[@class='f6 color-fg-muted mt-2']/a[2]"):
        contributors.append(i.text.replace('Contributors',''))
except NoSuchElementException:
    contributors.append('-')

# Scraping Languages used data
try:
    for i in driver.find_elements(By.XPATH,"//div[@class='f6 color-fg-muted mt-2']/span/span[2]"):
        language.append(i.text)
except NoSuchElementException:
    language.append('-')

# lets Create Dataframe
df=pd.DataFrame({})
df["Repositiry Title"]= repository_title[0:25]
df["Description"]=descrip[0:25]
df["Contributors"]=contributors[3:28]
df["Programming Langauge"]=language[0:25]
df
# Out:
#                                Repositiry Title  \
# 0                      teslamotors / light-show
# 1             youngyangyang04 / leetcode-master
# 2            donnemartin / system-design-primer
# 3                  Courseplay / Courseplay_FS22
# 4                             bitcoin / bitcoin
# 5                        sindresorhus / awesome
# 6                       R2Northstar / Northstar
# 7         mtdvio / every-programmer-should-know
# 8              trekhleb / javascript-algorithms
# 9                        alesimula / wsa_pacman
# 10                    mpcabete / bombcrypto-bot
# 11  Hackmanit / Web-Cache-Vulnerability-Scanner
# 12                        babysor / MockingBird
# 13                           Tinkoff / taiga-ui
# 14                             mkrl / misbrands
# 15              30-seconds / 30-seconds-of-code
# 16                            notthebee / infra
# 17                        bangle-io / bangle-io
# ...

# %% [markdown]
# Q6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url=" https:/www.billboard.com/"
driver.get(url)
time.sleep(2)

# %%
# click on charts
chart=driver.find_element(By.XPATH,"//li[@class='o-nav__list-item ']/a").click()

# %%
# lets create empty list
song_name=[]
artist_name=[]
last_week_rank=[]
peak_rank=[]
weeks_on_board=[]

# %%
# song names
for i in driver.find_elements(By.XPATH,"//li[@class='lrv-u-width-100p']/ul/li/h3"):
    song_name.append(i.text)
    
# artist names
for i in driver.find_elements(By.XPATH,"//li[@class='lrv-u-width-100p']/ul/li/span"):
    artist_name.append(i.text)
    
# last week ranks
for i in driver.find_elements(By.XPATH,"//li[@class='lrv-u-width-100p']/ul/li[4]/span"):
    last_week_rank.append(i.text)
    
# peak rank
for i in driver.find_elements(By.XPATH,"//li[@class='lrv-u-width-100p']/ul/li[5]/span"):
    peak_rank.append(i.text)
    
# weeks on board
for i in driver.find_elements(By.XPATH,"//li[@class='lrv-u-width-100p']/ul/li[6]/span"):
    weeks_on_board.append(i.text)
    
# Lets Create dataframe
df=pd.DataFrame({})
df['Name'] = song_name[0:100]
df['Artist'] = artist_name[0:100]
df['Last week rank'] = last_week_rank[0:100]
df['Peak rank'] = peak_rank[0:100]
df['Weeks on board'] = weeks_on_board[0:100]
df
# Out:
#                                  Name        Artist Last week rank Peak rank  \
# 0     All I Want For Christmas Is You  Mariah Carey              2         1
# 1   Rockin' Around The Christmas Tree             2              3         2
# 2                          Easy On Me             1              1         1
# 3                    Jingle Bell Rock            49              6         3
# 4             A Holly Jolly Christmas    Brenda Lee              5         4
# ..                                ...           ...            ...       ...
# 95                            No Love            11             78        13
# 96          Bad Man (Smooth Criminal)  Darlene Love             70        49
# 97                         Feel Alone            25              -        98
# 98                      Heart On Fire            17             95        89
# 99                             Bubbly            10             91        20
#
#    Weeks on board
# 0              49
# ...

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url=" https://www.naukri.com/"
driver.get(url)
time.sleep(2)

# %%
#opening recruiter page
recruiter = driver.find_element(By.XPATH,"//a[@title='Search Recruiters']")
page = recruiter.get_attribute("href")
driver.get(page)
time.sleep(2)

# %%
# Searching data science and clicking search button
search = driver.find_element(By.XPATH,"//div[@class='inpWrap']//input") 
search.send_keys("Data science")
time.sleep(2)

# %%
btn = driver.find_element(By.XPATH,"//button[@class='fl qsbSrch blueBtn']")
btn.click()
time.sleep(2)

# %%
# Lets create empty list
name=[]
designation=[]
company=[]
skills=[]
location=[]

# %%
#Names
for i in driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']"):
    name.append(i.text)
time.sleep(2)


#Designation
for i in driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']"):
    designation.append(i.text)
time.sleep(2)

#company name
for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/a[2]"):
    company.append(i.text)
time.sleep(2)
    
#Skills 
for i in driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        skills.append(i.text)
    except NoSuchElementException:
        skills.append('-')
    time.sleep(2)

#locations
for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]//span"):
    location.append(i.text)
time.sleep(2)

# Lets Create dataframe
df=pd.DataFrame({})
df['Name'] = name[:50]
df['Designation'] = designation[:50]
df['Company']=company[:50]
df['Skills'] = skills[:50]
df['Location'] = location[:50]
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %% [markdown]
# Q8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url="https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/"
driver.get(url)
time.sleep(2)

# %%
# lets create a list
book_name=[]
author_name=[]
volumes_sold=[]
publisher=[]
genre=[]

# %%
#book names
for i in driver.find_elements(By.XPATH,"//tbody//tr/td[2]"):
    book_name.append(i.text)

    
#author names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        author_name.append(i.text)
    except NoSuchElementException:
        author_name.append('-')
time.sleep(1)


#volumes sold
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[4]"):
    volumes_sold.append(i.text)

    
#publisher names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[5]"):
    publisher.append(i.text)

    
#genre
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[6]"):
    genre.append(i.text)
    
#Creating dataframe for scraped data
df=pd.DataFrame({})
df['Book Name'] = book_name
df['Author'] = author_name
df['Volume sold'] = volumes_sold
df['Publisher'] = publisher
df['Genre'] = genre
df
# Out:
# Empty DataFrame
# Columns: [Book Name, Author, Volume sold, Publisher, Genre]
# Index: []

# %% [markdown]
# Q9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url="https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(2)

# %%
# lets create empty list
Name=[]
year_span=[]
Genre=[]
run_time=[]
ratings=[]
votes=[]

# %%
#\ Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

#Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    year_span.append(i.text)

#genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)

#Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    run_time.append(i.text)

#Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    ratings.append(i.text)
    
#votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    votes.append(i.text)
    
# Lets Create dataframe
df=pd.DataFrame({})
df['Name'] = Name
df['Year Span'] = year_span
df['Genre'] = Genre
df['Run Time'] = run_time
df['Ratings'] = ratings
df['Votes'] = votes
df
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,919,745
# ...

# %% [markdown]
# Q10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
# Extracting path of the Webdriver//div[@id='productOverview_feature_div']/div/table/tbody/tr/td[2]/span
path=Service("C:\\Users\\amitt\\Downloads\\chromedriver_win32\\chromedriver.exe")
driver= webdriver.Chrome(service=path)

#Opening the required website
url="https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)

# %%
# click on view all dataset button from the homepage
view= driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")    
page_url = view.get_attribute("href")
driver.get(page_url)
time.sleep(2)

# %%
# lets create an empty list
dataset_name=[]
datatype=[]
task=[]
attribute_type=[]
no_of_instances=[]
no_of_attributes=[]
Year=[]

# %%
#Dataset name
try: 
    for i in driver.find_elements(By.XPATH,"//span[@class='heading']"):
        dataset_name.append(i.text)
except NoSuchElementException:
    dataset_name.append('-')
time.sleep(2)
    
#data type
try:
    for i in driver.find_elements(By.XPATH,"//table[@border='1']//tbody/tr/td[2]"):
        datatype.append(i.text)
except NoSuchElementException:
    datatype.append('-')
time.sleep(2)
    
#Task
try:
    for i in driver.find_elements(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]"):
        task.append(i.text)
except NoSuchElementException:
        task.append('-')
time.sleep(2)

#Attribute
try:
    for i in driver.find_elements(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]"):
        attribute_type.append(i.text)
except NoSuchElementException:
    attribute_type.append('-')
time.sleep(2)
    
#No of instances
try:
    for i in driver.find_elements(By.XPATH,"//table[@border='1']//tbody/tr/td[4]"):
        no_of_instances.append(i.text)
except NoSuchElementException:
    no_of_instances.append('-')
time.sleep(2)
    
# No of attributes
try:
    for i in driver.find_elements(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]"):
        no_of_attributes.append(i.text)
except NoSuchElementException:
    no_of_attributes.append('-')
time.sleep(2)
    
# year
try:
    for i in driver.find_elements(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]"):
        Year.append(i.text[:4])
except NoSuchElementException:
    Year.append('-')
time.sleep(2)

# lets create a DataFrame
df=pd.DataFrame({})
df['Data Name'] = dataset_name[:3]
df['Data Type'] = datatype[:3]
df['Task'] = task[:3]
df['Attribute type'] = attribute_type[:3]
df['No of instance'] = no_of_instances[:3]
df['No of attributes'] = no_of_attributes[:3]
df['Year'] = Year[:3]
df
# Out:
#   Data Name   Data Type           Task Attribute type   No of instance  \
# 0         -  Data Types  Multivariate   Multivariate   Attribute Types
# 1         -  Data Types  Multivariate   Multivariate   Attribute Types
# 2         -  Data Types  Multivariate   Multivariate   Attribute Types
#
#               No of attributes Year
# 0  Categorical, Integer, Real    8
# 1  Categorical, Integer, Real    8
# 2  Categorical, Integer, Real    8
